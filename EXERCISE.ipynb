# %% [markdown]
# # PROBLEM 1: CREATE A FUNCTION TO IDENTIFY A NUMBER IS PRIME OR NOT
# HINT: INPUT--> NUMBER , OUTPUT--> PRINT THE RESULT IS PRIME OR NOT

# %% [markdown]
# # PROBLEM 2: WRITE A FUNCTION WHICH GIVEN A NUMBERS IN A LIST. FIND NUMBERS WHICH ARE DIVISIVIBLE BY 5
#
# EXAMPLE: IN THE LIST a = [5,4,10,3,49,84], THE OUTPUTS ARE 5,10

# %% [markdown]
# # PROBLEM 3: NUMPY ARRAY EXERCISE
#
# a) Create an array has 10 zeros
#
# b) Create an array has 10 ones
# c) Create an array of the integers from 10 to 50
#
# d) Create a 3x3 matrix with values ranging from 0 to 8
#
# e) Use NumPy to generate a random number between 0 and 1

# %% [markdown]
# # PROBLEM 4: NUMPY ARRAY INDEXING
#
# a) Find the first element of an array x1
#
# b) Find the elements has index from the second to fourth elements of the array x1 (output would be [5,2,20])
#
# c) Find the third element in the array x1
#
# d) Find the first row of the matrix x2
#
# e) Find the element in the row 1 and column 3 in the matrix x2 ( output would be 6)
#
#
# https://www.w3resource.com/python-exercises/numpy/index.php

# %%
import numpy as np

x1 = np.array([4,5,2,20,15])

x2 = np.array([[2,5,6],[7,9,10]])
x2
# Out:
# array([[ 2,  5,  6],
#        [ 7,  9, 10]])

# %% [markdown]
# # PROBLEM 5: PANDAS EXERCISE
#
# a) Import the dataset bank.csv
#
# b) Display the first 5 rows of the data set
#
# c) What is the average (mean) age of the people in the dataset?
#
# d) What is the marital status of the youngest person in the dataset?
#
# e) How many unique job categories are there?
#
# f) What percent of people in the dataset were married?
